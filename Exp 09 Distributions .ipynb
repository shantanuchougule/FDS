# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import poisson

# %%
#Loading the dataset
df =pd.read_csv("bombay.csv")
df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2009-01-01 00:00:00        30        22           0.0     11.0        7
# 1  2009-01-01 01:00:00        30        22           0.0     11.0        7
# 2  2009-01-01 02:00:00        30        22           0.0     11.0        7
# 3  2009-01-01 03:00:00        30        22           0.0     11.0        7
# 4  2009-01-01 04:00:00        30        22           0.0     11.0        7
#
#    uvIndex.1  moon_illumination  moonrise   moonset  ... WindChillC  \
# 0          1                 31  10:21 AM  10:20 PM  ...         27
# 1          1                 31  10:21 AM  10:20 PM  ...         26
# 2          1                 31  10:21 AM  10:20 PM  ...         26
# 3          1                 31  10:21 AM  10:20 PM  ...         25
# 4          1                 31  10:21 AM  10:20 PM  ...         26
#
#   WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %% [markdown]
# # 1. Normal Distribution:

# %%
sns.kdeplot(data=df['humidity'])
plt.xlabel('Range of humidity')
plt.ylabel('Density')
plt.title('Normal Distribution Plot of Bombay temperature')
plt.show()

# %% [markdown]
# # 2. Poisson Distribution:

# %%
lambda_av = df["maxtempC"].mean()
print(lambda_av)

n_points = 1000
poisson_data = np.random.poisson(lam=lambda_av, size=n_points)

sns.displot(poisson_data, kde=False, color='purple')
plt.xlabel('Maximum Temperature')
plt.ylabel('Frequency')
plt.title('Poisson Distribution of maxtemp in Bombay ')
# Out:
# 30.761075161772027
# Text(0.5, 1.0, 'Poisson Distribution of maxtemp in Bombay ')

# %% [markdown]
# # 3. Uniform Distribution

# %%
sns.distplot(np.random.uniform(size=5000), hist=True)
# Out:
# C:\Users\Aayush Vadagaonkar\AppData\Local\Temp\ipykernel_19236\840894716.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.uniform(size=5000), hist=True)
# <Axes: ylabel='Density'>

# %% [markdown]
# # 4. Gamma Distribution

# %%
#Importing the required library 

from scipy.stats import gamma

data_column = "pressure"

shape, loc, scale = gamma.fit(df[data_column])

x = np.linspace(min(df[data_column]), max(df[data_column]), 100)
gamma_pdf = gamma.pdf(x, shape, loc=loc, scale=scale)

sns.kdeplot(df[data_column], shade=True, label="Data Distribution", color = 'green') 
plt.plot(x, gamma_pdf, label="Fitted Gamma Distribution")
plt.xlabel(data_column)
plt.ylabel("Density") 
plt.title("Gamma Distribution Fit to " + data_column)
plt.legend() 
plt.show()
# Out:
# C:\Users\Aayush Vadagaonkar\AppData\Local\Temp\ipykernel_19236\3440504464.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[data_column], shade=True, label="Data Distribution", color = 'green')

# %%
# Here we've seen different types of data distributions 
# applicable for data science
